# %%
import pandas as pd

# %% [markdown]
# # Vertical Concatenation

# %% [markdown]
# ## Download Data

# %% [markdown]
# Create the local directory *data* and download the dataset files (2015.csv, 2016.csv, 2017.csv) published at the link https://www.kaggle.com/unsdsn/world-happiness to the local data directory.

# %% [markdown]
# ## Processing

# %%
# load data
whr_2015 = pd.read_csv('data/2015.csv', sep=',')
whr_2016 = pd.read_csv('data/2016.csv', sep=',')
whr_2017 = pd.read_csv('data/2017.csv', sep=',')

# set the year variable to distinguish rows in the combined data frame later
whr_2015['year'] = 2015
whr_2016['year'] = 2016
whr_2016['year'] = 2017

print(whr_2015.shape)
print(whr_2016.shape)
print(whr_2017.shape)
# Out:
# (158, 13)
# (157, 14)
# (155, 12)

# %%
whr = pd.concat([whr_2015, whr_2016], axis=0, sort=False)

print(whr.shape)
# Out:
# (315, 15)

# %%
whr_2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual  year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015

# %%
whr_2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.44453     0.36171            2.73939  2017
# 1                        0.41203     0.28083            2.69463  2017

# %%
whr.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual  year  Lower Confidence Interval  \
# 0     0.29678            2.51738  2015                        NaN
# 1     0.43630            2.70201  2015                        NaN
#
#    Upper Confidence Interval
# 0                        NaN
# 1                        NaN

# %% [markdown]
# # Horizontal Concatenation

# %% [markdown]
# ## Download Data
#
# Create the local directory *data* and download the dataset file (countries of the world.csv) published at the link https://www.kaggle.com/fernandol/countries-of-the-world to the local data directory.

# %% [markdown]
# ## Processing

# %%
whr_2017 = pd.read_csv('data/2017.csv', sep=',')
countries = pd.read_csv('data/countries of the world.csv', sep=',')

# removing spaces around the country names so as to match them with the names in whr_2017 later
countries['Country'] = countries['Country'].str.strip()

# %%
# setting the index which will be used to combine two data frame 'horizontally'
whr_2017 = whr_2017.set_index('Country')
countries = countries.set_index('Country')

# %%
print(whr_2017.shape)
print(countries.shape)
# Out:
# (155, 11)
# (227, 19)

# %%
whr_2017_ext = pd.concat([whr_2017, countries], axis=1, sort=False, ignore_index=False, join='inner')

print(whr_2017_ext.shape)
# Out:
# (140, 30)

# %%
whr_2017_ext.head(10)
# Out:
#              Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# Country
# Norway                    1            7.537      7.594445     7.479556
# Denmark                   2            7.522      7.581728     7.462272
# Iceland                   3            7.504      7.622030     7.385970
# Switzerland               4            7.494      7.561772     7.426227
# Finland                   5            7.469      7.527542     7.410458
# Netherlands               6            7.377      7.427426     7.326574
# Canada                    7            7.316      7.384403     7.247597
# New Zealand               8            7.314      7.379510     7.248490
# Sweden                    9            7.284      7.344095     7.223905
# Australia                10            7.284      7.356651     7.211349
#
#              Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# Country
# Norway                       1.616463  1.533524                  0.796667
# Denmark                      1.482383  1.551122                  0.792566
# Iceland                      1.480633  1.610574                  0.833552
# Switzerland                  1.564980  1.516912                  0.858131
# Finland                      1.443572  1.540247                  0.809158
# Netherlands                  1.503945  1.428939                  0.810696
# Canada                       1.479204  1.481349                  0.834558
# New Zealand                  1.405706  1.548195                  0.816760
# Sweden                       1.494387  1.478162                  0.830875
# Australia                    1.484415  1.510042                  0.843887
#
#               Freedom  Generosity  Trust..Government.Corruption.  ...  \
# Country                                                           ...
# Norway       0.635423    0.362012                       0.315964  ...
# Denmark      0.626007    0.355280                       0.400770  ...
# Iceland      0.627163    0.475540                       0.153527  ...
# Switzerland  0.620071    0.290549                       0.367007  ...
# Finland      0.617951    0.245483                       0.382612  ...
# Netherlands  0.585384    0.470490                       0.282662  ...
# Canada       0.611101    0.435540                       0.287372  ...
# New Zealand  0.614062    0.500005                       0.382817  ...
# Sweden       0.612924    0.385399                       0.384399  ...
# Australia    0.601607    0.477699                       0.301184  ...
#
#              Phones (per 1000) Arable (%)  Crops (%)  Other (%) Climate  \
# Country
# Norway                   461,7       2,87          0      97,13       3
# Denmark                  614,6      54,02       0,19      45,79       3
# Iceland                  647,7       0,07          0      99,93       3
# Switzerland              680,9      10,42       0,61      88,97       3
# Finland                  405,3       7,19       0,03      92,78       3
# Netherlands              460,8      26,71       0,97      72,32       3
# Canada                   552,2       4,96       0,02      95,02     NaN
# New Zealand              441,7        5,6       6,99      87,41       3
# Sweden                   715,0       6,54       0,01      93,45       3
# Australia                565,5       6,55       0,04      93,41       1
#
#             Birthrate Deathrate Agriculture  Industry Service
# Country
# Norway          11,46       9,4       0,021     0,415   0,564
# Denmark         11,13     10,36       0,018     0,246   0,735
# Iceland         13,64      6,72       0,086      0,15   0,765
# Switzerland      9,71      8,49       0,015      0,34   0,645
# Finland         10,45      9,86       0,028     0,295   0,676
# Netherlands      10,9      8,68       0,021     0,244   0,736
# Canada          10,78       7,8       0,022     0,294   0,684
# New Zealand     13,76      7,53       0,043     0,273   0,684
# Sweden          10,27     10,31       0,011     0,282   0,707
# Australia       12,14      7,51       0,038     0,262     0,7
#
# [10 rows x 30 columns]
